# %% [markdown]
# Note: 2017 was the first year where PKWs had a category for "Elektro". Before that, there was only a category for "sonstige". (Years from 2017 have both categories.)
#
# Data from https://www.kba.de/DE/Statistik/Produktkatalog/produkte/Fahrzeuge/fz1_b_uebersicht.html

# %%
import pandas as pd

# %% [markdown]
# ## Making dataframes from the years where we have a CSV

# %% [markdown]
# This is for all years 2013 to 2017 inclusive.

# %%
#List of columns that we want as they are listed in CSV files. New list uses Python numbering.
csv_col_list = [1,7,19,21,36,37,40,41,44,45,46,47,48,49,50,51,52]
py_col_list = [i - 1 for i in csv_col_list]

#function to import a CSV file for a year into a dataframe
def CSVtoPD(year):
    filepath = "data/" + str(year) + " formatted.csv"
    
    #removes columns and rows that we don't want
    df = pd.read_csv(filepath,usecols=py_col_list)
    df = df.drop([0],axis=0)
    
    #change column names
    df.rename(columns = {'Unnamed: 0':'Place'}, inplace = True)
    
    return(df)

# %%
df2013 = CSVtoPD(2013)
df2014 = CSVtoPD(2014)
df2015 = CSVtoPD(2015)
df2016 = CSVtoPD(2016)
df2017 = CSVtoPD(2017)

# %%
df2013
# Out:
#                         Place PKW insgesamt PKW Dichte (je 1 000 Einwohner)  \
# 1                      Berlin       1149520                             328
# 2                     Hamburg        738610                             411
# 3             München (09162)        674394                             489
# 4                Köln (05315)        445134                             438
# 5   Frankfurt am Main (06412)        313385                             453
# 6           Stuttgart (08111)        281351                             459
# 7          Düsseldorf (05111)        289306                             488
# 8             Leipzig (14713)        203571                             383
# 9                    Dortmund        290036                             449
# 10                      Essen        268827                             469
#
#    LKW insgesamt Kraftfahrzeuge insgesamt  \
# 1          81085                  1344876
# 2          48254                   850335
# 3          31259                   771625
# 4          26226                   511906
# 5          20372                   356757
# 6          12613                   319631
# 7          15464                   331679
# 8          13570                   230691
# 9          12805                   299285
# 10         15043                   307943
#
#    Kraftfahrzeuge Dichte (je 1000 Einwohner) PKW Benzin PKW Diesel  \
# 1                                        384     879752     248543
# 2                                        473     505121     225682
# 3                                        560     414201     254025
# 4                                        503     298983     139311
# 5                                        516     187159     122434
# 6                                        521     182981      95234
# 7                                        560     181101     104123
# 8                                        434     157598      42717
# 9                                        515     189923      66955
# 10                                       537     196104      67534
#
#    PKW sonstige Energiequelle PKW Emissionsgruppe Euro 1  \
# 1                        4657                      56948
# 2                        1674                      28744
# 3                        2263                      26717
# 4                        1659                      19264
# 5                         946                      12440
# 6                        1241                       9685
# 7                         690                      12542
# 8                         646                       7670
# 9                         411                      11200
# 10                        414                      11182
#
#    PKW Emissionsgruppe Euro 2 PKW Emissionsgruppe Euro 3  \
# 1                      227817                     177838
# 2                      119399                     105282
# 3                       90768                      88775
# 4                       73311                      67797
# 5                       45577                      39782
# 6                       45078                      38462
# 7                       44769                      40074
# 8                       35009                      32276
# 9                       49374                      41292
# 10                      43567                      40868
#
#    PKW Emissionsgruppe Euro 4 PKW Emissionsgruppe Euro 5  \
# 1                      445819                     222607
# 2                      272529                     194579
# 3                      222913                     218484
# 4                      165743                     104242
# 5                      105253                     102374
# 6                       99204                      82188
# 7                      101290                      83142
# 8                       85499                      40892
# 9                      103830                      50289
# 10                     107429                      57776
#
#    PKW Emissionsgruppe Euro 6 PKW Emissionsgruppe sonstige  \
# 1                        2204                         2621
# 2                        2097                         3912
# 3                        2635                         8297
# 4                         613                         2127
# 5                         862                         1011
# 6                        1915                          657
# 7                         854                         1408
# 8                         236                          453
# 9                         345                         1138
# 10                        392                          540
#
#    PKW Emissionsgruppe schadstoffreduzierte insgesamt
# 1                                             1135854
# 2                                              726542
# 3                                              658589
# 4                                              433097
# 5                                              307299
# 6                                              277189
# 7                                              284079
# 8                                                1536
# 9                                              257468
# 10                                             265889

# %% [markdown]
# ## Making dataframes from the years where we have a .xlsx

# %% [markdown]
# This is for all years 2018 to 2022 inclusive.
# The 2018 Excel file is structured slightly differently to the other Excel files - I edited it in Excel to make it consistent so that it can use the same function.

# %%
#these numbers are used in the spreadsheet to identify our 10 cities
cities = "11000|02000|09162|05315|06412|08111|05111|14713|05913|05113"

#function to turn an .XLSX file for year into a df
def ExceltoDF(year):
    #generate filepath for the relevant year
    filepath = "data/fz1_" + str(year) + ".xlsx"
    
    #read sheet FZ1.1 from that file path, skip first 8 roads, skip columns without header names
    df1 = pd.read_excel(filepath, sheet_name='FZ1.1',skiprows=8,usecols=lambda x: 'Unnamed' not in x)

    #fill the merged cells with the corresponding value
    df1 = df1.fillna(method='ffill')

    #remove the final 5 rows. They don't have relevant data and are in a different format.
    df1 = df1[:-6]
    
    #same as above for most of sheet 2
    #the Excel formatting makes it hard to get the columns before Benzin but they're not needed
    df2 = pd.read_excel(filepath, sheet_name='FZ1.2',skiprows=8,usecols=lambda x: 'Unnamed' not in x)
    df2 = df2.fillna(method='ffill')
    df2 = df2[:-5]
    
    #combines the dataframes from each of the sheets
    df = pd.concat([df1, df2], axis=1)
    
    #filters the dataframe to only show rows with our 10 cities    
    df = df.dropna(subset=['Statistische Kennziffer und Zulassungsbezirk'])
    df = df.loc[df['Statistische Kennziffer und Zulassungsbezirk'].str.contains(cities)]
    
    #Berlin and Hamburg are cities and Länder so this line is needed to stop them from being duplicated in the df
    df = df.loc[df["Land"].str.contains('INSGESAMT')==False]
    
    #remove unnecessary columns
    df = df.iloc[:,[2,8,19,20,33,34,35,36,40,42,43,44,45,46,47,50,51]]

    #renames the columns
    df.columns = df.columns.str.replace('Euro', 'PKW Emissionsgruppe Euro')
    df.rename(columns = {'insgesamt.1':'PKW insgesamt', 
                         'PKW-Dichte\nje 1.000 \nEinwohner':'PKW Dichte',
                         'insgesamt.2':'LKW insgesamt',
                         'insgesamt.4':'KFZ insgesamt',
                         'Kfz-Dichte\nje 1.000 \nEinwohner':'KFZ Dichte',
                         'sonstige.1':'PKW Emissionsgruppe sonstige',
                         'schadstoff-\nreduzierte \ninsgesamt':'PKW Emissionsgruppe schadstoffreduzierte insgesamt'}, inplace = True)
    
    return(df)

# %%
df2018 = ExceltoDF(2018)
df2019 = ExceltoDF(2019)
df2020 = ExceltoDF(2020)
df2021 = ExceltoDF(2021)
df2022 = ExceltoDF(2022)

# %%
df2018
# Out:
#     Statistische Kennziffer und Zulassungsbezirk  PKW insgesamt PKW Dichte  \
# 0       08111  STUTTGART,STADT                         301508.0        483
# 50      09162  MUENCHEN,STADT                          727179.0        501
# 153      11000  BERLIN                                1202829.0        342
# 177     02000  HAMBURG                                 783255.0        438
# 180     06412  FRANKFURT AM MAIN,STADT                 333768.0        456
# 268     05111  DUESSELDORF, STADT                      307571.0        502
# 270     05113  ESSEN,STADT                             285071.0        489
# 285     05315  KOELN,STADT                             480332.0        453
# 314     05913  DORTMUND,STADT                          282290.0        482
# 385     14713  LEIPZIG, STADT                          223734.0        399
#
#      LKW insgesamt  KFZ insgesamt KFZ Dichte    Benzin    Diesel  Elektro  \
# 0          16037.0       346429.0        555  189027.0  106608.0   1193.0
# 50         36793.0       838275.0        578  424574.0  288961.0   2287.0
# 153        96943.0      1422065.0        404  863140.0  307976.0   2007.0
# 177        56640.0       907426.0        508  504715.0  265809.0   1387.0
# 180        22358.0       381530.0        521  186420.0  141909.0    527.0
# 268        16061.0       352030.0        575  183176.0  118266.0    404.0
# 270        16040.0       326352.0        560  201491.0   77238.0    234.0
# 285        30214.0       554919.0        523  308304.0  161866.0    750.0
# 314        14019.0       322549.0        550  196743.0   80198.0    224.0
# 385        15240.0       255092.0        455  161872.0   57244.0    302.0
#
#      PKW Emissionsgruppe Euro 1  PKW Emissionsgruppe Euro 2  \
# 0                        4624.0                     22423.0
# 50                      14000.0                     44746.0
# 153                     22417.0                    112777.0
# 177                     13454.0                     59575.0
# 180                      5159.0                     22429.0
# 268                      5645.0                     22568.0
# 270                      4320.0                     23558.0
# 285                      8214.0                     36113.0
# 314                      4494.0                     24474.0
# 385                      2883.0                     17085.0
#
#      PKW Emissionsgruppe Euro 3  PKW Emissionsgruppe Euro 4  \
# 0                       23531.0                     73801.0
# 50                      52779.0                    165291.0
# 153                    119537.0                    366516.0
# 177                     67286.0                    213438.0
# 180                     25709.0                     82794.0
# 268                     24962.0                     77702.0
# 270                     26568.0                     86096.0
# 285                     43479.0                    137721.0
# 314                     27396.0                     88984.0
# 385                     20723.0                     70511.0
#
#      PKW Emissionsgruppe Euro 5  PKW Emissionsgruppe Euro 6  \
# 0                       73009.0                     97405.0
# 50                     173195.0                    252961.0
# 153                    311836.0                    249216.0
# 177                    200184.0                    211073.0
# 180                     80938.0                    108853.0
# 268                     78259.0                     90912.0
# 270                     76435.0                     63926.0
# 285                    118767.0                    125440.0
# 314                     75001.0                     57000.0
# 385                     63316.0                     46343.0
#
#      PKW Emissionsgruppe sonstige  \
# 0                          5356.0
# 50                        17399.0
# 153                       16951.0
# 177                       13695.0
# 180                        6666.0
# 268                        6249.0
# 270                        3616.0
# 285                        8502.0
# 314                        3963.0
# 385                        2241.0
#
#      PKW Emissionsgruppe schadstoffreduzierte insgesamt
# 0                                                180.0
# 50                                              1352.0
# 153                                             1471.0
# 177                                             2093.0
# 180                                              217.0
# 268                                              303.0
# 270                                              149.0
# 285                                              514.0
# 314                                              258.0
# 385                                              148.0
